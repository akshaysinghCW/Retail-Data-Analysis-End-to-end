# %% [markdown]
# **Pre request**

# %% [markdown]
# **1.pip install snowflake-connector-python**
#
# **2.pip install snowflake-sqlalchemy**
#
# **3.pip install "snowflake-connector-python[pandas]"**

# %%
pip install --upgrade numba
# Out:
# Requirement already satisfied: numba in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (0.59.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from numba) (0.42.0)
# Requirement already satisfied: numpy<1.27,>=1.22 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from numba) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas pandas_profiling
# Out:
# Requirement already satisfied: pandas in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: pandas_profiling in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: joblib~=1.1.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.11.4)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (3.8.0)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (4.66.1)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.11.2)
# Requirement already satisfied: attrs>=19.3.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (3.1)
# Requirement already satisfied: imagehash in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.3.1)
# Requirement already satisfied: Pillow in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (10.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas_profiling) (4.9.0)
# Requirement already satisfied: six>=1.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (2024.2.2)
# Requirement already satisfied: PyWavelets in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (1.26.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a new virtual environment (for example, with venv)
# !python -m venv new_env
# Activate the environment

# On macOS/Linux
# !source new_env/bin/activate
# Install libraries
# !pip install pandas pandas_profiling numba
# Out:
# Requirement already satisfied: pandas in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: pandas_profiling in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: numba in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (0.59.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: joblib~=1.1.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.11.4)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (3.8.0)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (4.66.1)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pandas_profiling) (1.11.2)
# Requirement already satisfied: attrs>=19.3.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (3.1)
# Requirement already satisfied: imagehash in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.3.1)
# Requirement already satisfied: Pillow in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (10.0.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from numba) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas_profiling) (4.9.0)
# Requirement already satisfied: six>=1.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas_profiling) (2024.2.2)
# Requirement already satisfied: PyWavelets in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.4.1)

# %%
pip install snowflake
# Out:
# Requirement already satisfied: snowflake in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: snowflake-core==0.6.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake) (0.6.0)
# Requirement already satisfied: snowflake-legacy in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake) (0.5.0)
# Requirement already satisfied: atpublic>=4 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-core==0.6.0->snowflake) (4.0)
# Requirement already satisfied: pydantic>=1.10.7 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-core==0.6.0->snowflake) (1.10.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-core==0.6.0->snowflake) (2.8.2)
# Requirement already satisfied: snowflake-snowpark-python<2.0.0,>=1.5.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-core==0.6.0->snowflake) (1.13.0)
# Requirement already satisfied: urllib3 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-core==0.6.0->snowflake) (2.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from pydantic>=1.10.7->snowflake-core==0.6.0->snowflake) (4.9.0)
# Requirement already satisfied: six>=1.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->snowflake-core==0.6.0->snowflake) (1.16.0)
# Requirement already satisfied: setuptools>=40.6.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (69.0.3)
# Requirement already satisfied: wheel in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (0.38.4)
# Requirement already satisfied: snowflake-connector-python<4.0.0,>=3.6.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (3.7.1)
# Requirement already satisfied: pyyaml in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (6.0.1)
# Requirement already satisfied: cloudpickle==2.2.1 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2.2.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (41.0.7)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (23.2.0)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2.4.0)
# Requirement already satisfied: pytz in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2.31.0)
# Requirement already satisfied: packaging in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2024.2.2)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2.4.0)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (3.10.0)
# Requirement already satisfied: tomlkit in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (0.11.1)
# Requirement already satisfied: pycparser in /Users/akshaysingh/anaconda3/lib/python3.11/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core==0.6.0->snowflake) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
#import pandas_profiling 
import matplotlib.pyplot as plt 
import getpass
import seaborn as sns 
# %matplotlib inline
import snowflake.connector

# %% [markdown]
# **Connecting to Snowflake**

# %%
conn = snowflake.connector.connect(
    user='akshaysingh',
    password='Turtleking23!',
    account='HFZNEEE-XK27295',  # Adjusted account format
    database='RETAIL',
    schema='PUBLIC',
    warehouse='COMPUTE_WH',
)

# %%
cur = conn.cursor()

# %%
select_demographic_RAW = 'SELECT * FROM demographic_RAW'
select_CAMPAIGN_DESC_RAW = 'SELECT * FROM CAMPAIGN_DESC_RAW'
select_CAMPAIGN_RAW = 'SELECT * FROM CAMPAIGN_RAW'
select_PRODUCT_RAW = 'SELECT * FROM PRODUCT_RAW'
select_COUPON_RAW = 'SELECT * FROM COUPON_RAW'
select_COUPON_REDEMPT_RAW = 'SELECT * FROM COUPON_REDEMPT_RAW'
select_TRANSACTION_RAW = 'SELECT * FROM TRANSACTION_RAW'

# %%
cur.execute(select_demographic_RAW)
demographic_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_CAMPAIGN_DESC_RAW)
CAMPAIGN_DESC_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_CAMPAIGN_RAW)
CAMPAIGN_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_PRODUCT_RAW)
PRODUCT_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_COUPON_RAW)
COUPON_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_COUPON_REDEMPT_RAW)
COUPON_REDEMPT_RAW = cur.fetch_pandas_all()

# %%
cur.execute(select_TRANSACTION_RAW)
TRANSACTION_RAW = cur.fetch_pandas_all()

# %%
cur.close()
conn.close()

# %%
demographic_RAW.head(5)
# Out:
#   AGE_DESC MARITAL_STATUS_CODE INCOME_DESC HOMEOWNER_DESC      HH_COMP_DESC  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
# 2    25-34                   U      25-34K        Unknown     2 Adults Kids
# 3    25-34                   U      75-99K      Homeowner     2 Adults Kids
# 4    45-54                   B      50-74K      Homeowner     Single Female
#
#   HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC  HOUSEHOLD_KEY
# 0                   2      None/Unknown              1
# 1                   2      None/Unknown              7
# 2                   3                 1              8
# 3                   4                 2             13
# 4                   1      None/Unknown             16

# %%
CAMPAIGN_DESC_RAW.head(5)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 0       TypeB        24        659      719
# 1       TypeC        15        547      708
# 2       TypeB        25        659      691
# 3       TypeC        20        615      685
# 4       TypeB        23        646      684

# %%
CAMPAIGN_RAW.head(5)
# Out:
#   DESCRIPTION  HOUSEHOLD_KEY  CAMPAIGN
# 0       TypeA             17        26
# 1       TypeA             27        26
# 2       TypeA            212        26
# 3       TypeA            208        26
# 4       TypeA            192        26

# %%
PRODUCT_RAW.head(5)
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
COUPON_RAW.head(5)
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25

# %%
COUPON_REDEMPT_RAW.head(5)
# Out:
#    HOUSEHOLD_KEY  DAY   COUPON_UPC  CAMPAIGN
# 0              1  421  10000085364         8
# 1              1  421  51700010076         8
# 2              1  427  54200000033         8
# 3              1  597  10000085476        18
# 4              1  597  54200029176        18

# %%
TRANSACTION_RAW.head(5)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       364        -0.60        1631        1            0                  0
# 1       364         0.00        1631        1            0                  0
# 2       364        -0.30        1631        1            0                  0
# 3       364         0.00        1631        1            0                  0
# 4       364        -0.39        1631        1            0                  0

# %%
TRANSACTION_RAW.dtypes
# Out:
# HOUSEHOLD_KEY          int16
# BASKET_ID              int64
# DAY                    int16
# PRODUCT_ID             int32
# QUANTITY               int32
# SALES_VALUE          float64
# STORE_ID               int16
# RETAIL_DISC          float64
# TRANS_TIME             int16
# WEEK_NO                 int8
# COUPON_DISC             int8
# COUPON_MATCH_DISC       int8
# dtype: object

# %%
CAMPAIGN_DESC_RAW.shape
# Out:
# (30, 4)

# %%
COUPON_REDEMPT_RAW.shape
# Out:
# (2318, 4)

# %%
COUPON_RAW.shape
# Out:
# (124548, 3)

# %%
demographic_RAW.shape
# Out:
# (2500, 8)

# %%
PRODUCT_RAW.shape
# Out:
# (92353, 7)

# %%
TRANSACTION_RAW.shape
# Out:
# (450416, 12)

# %%
CAMPAIGN_DESC_RAW.isnull().sum()
# Out:
# DESCRIPTION    0
# CAMPAIGN       0
# START_DAY      0
# END_DAY        0
# dtype: int64

# %%
CAMPAIGN_DESC_RAW.describe()
# Out:
#         CAMPAIGN   START_DAY     END_DAY
# count  30.000000   30.000000   30.000000
# mean   15.500000  463.866667  510.466667
# std     8.803408  134.488490  137.730555
# min     1.000000  224.000000  264.000000
# 25%     8.250000  360.000000  405.750000
# 50%    15.500000  470.000000  502.000000
# 75%    22.750000  584.000000  640.250000
# max    30.000000  659.000000  719.000000

# %%
PRODUCT_RAW.isnull().sum()
# Out:
# PRODUCT_ID              0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %%
PRODUCT_RAW.describe()
# Out:
#          PRODUCT_ID  MANUFACTURER
# count  9.235300e+04   92353.00000
# mean   5.328353e+06    1739.22833
# std    5.359937e+06    1818.26957
# min    2.567100e+04       1.00000
# 25%    9.706280e+05     328.00000
# 50%    1.621091e+06    1094.00000
# 75%    9.704770e+06    2264.00000
# max    1.831630e+07    6477.00000

# %%
demographic_RAW.isnull().sum()
# Out:
# AGE_DESC               0
# MARITAL_STATUS_CODE    0
# INCOME_DESC            0
# HOMEOWNER_DESC         0
# HH_COMP_DESC           0
# HOUSEHOLD_SIZE_DESC    0
# KID_CATEGORY_DESC      0
# HOUSEHOLD_KEY          0
# dtype: int64

# %%
demographic_RAW.describe()
# Out:
#        HOUSEHOLD_KEY
# count     2500.00000
# mean      1250.50000
# std        721.83216
# min          1.00000
# 25%        625.75000
# 50%       1250.50000
# 75%       1875.25000
# max       2500.00000

# %%
COUPON_RAW.isnull().sum()
# Out:
# COUPON_UPC    0
# PRODUCT_ID    0
# CAMPAIGN      0
# dtype: int64

# %%
demographic_RAW.describe()
# Out:
#        HOUSEHOLD_KEY
# count     2500.00000
# mean      1250.50000
# std        721.83216
# min          1.00000
# 25%        625.75000
# 50%       1250.50000
# 75%       1875.25000
# max       2500.00000

# %%
COUPON_REDEMPT_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY    0
# DAY              0
# COUPON_UPC       0
# CAMPAIGN         0
# dtype: int64

# %%
COUPON_REDEMPT_RAW.describe()
# Out:
#        HOUSEHOLD_KEY          DAY    COUPON_UPC     CAMPAIGN
# count    2318.000000  2318.000000  2.318000e+03  2318.000000
# mean     1302.816652   528.217429  4.123049e+10    15.551337
# std       783.002545   100.360985  1.986068e+10     5.716636
# min         1.000000   225.000000  1.000009e+10     1.000000
# 25%       588.000000   458.250000  1.000009e+10    13.000000
# 50%      1396.500000   532.000000  5.234003e+10    14.000000
# 75%      2004.000000   605.000000  5.430002e+10    18.000000
# max      2500.000000   704.000000  5.897850e+10    30.000000

# %%
TRANSACTION_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# TRANS_TIME           0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# dtype: int64

# %%
TRANSACTION_RAW.describe()
# Out:
#        HOUSEHOLD_KEY     BASKET_ID            DAY    PRODUCT_ID  \
# count   450416.00000  4.504160e+05  450416.000000  4.504160e+05
# mean      1259.55822  2.840143e+10     112.470718  2.209464e+06
# std        728.10869  5.792110e+08      42.064258  2.726512e+06
# min          1.00000  2.698485e+10       1.000000  2.567100e+04
# 25%        641.00000  2.798531e+10      84.000000  9.118780e+05
# 50%       1234.00000  2.839168e+10     117.000000  1.016800e+06
# 75%       1914.00000  2.886773e+10     147.000000  1.115360e+06
# max       2500.00000  2.933965e+10     176.000000  1.260019e+07
#
#             QUANTITY    SALES_VALUE       STORE_ID    RETAIL_DISC  \
# count  450416.000000  450416.000000  450416.000000  450416.000000
# mean       86.522561       3.018436    2586.661648      -0.552774
# std      1058.788785       3.860427    7996.435988       1.186736
# min         0.000000       0.000000       1.000000     -75.000000
# 25%         1.000000       1.250000     330.000000      -0.740000
# 50%         1.000000       2.000000     369.000000      -0.090000
# 75%         1.000000       3.390000     421.000000       0.000000
# max     51912.000000     400.000000   32124.000000       0.000000
#
#           TRANS_TIME        WEEK_NO    COUPON_DISC  COUPON_MATCH_DISC
# count  450416.000000  450416.000000  450416.000000      450416.000000
# mean     1583.582364      16.754487      -0.014860          -0.001920
# std       415.130098       6.018864       0.195378           0.044335
# min         0.000000       1.000000     -17.000000          -3.000000
# 25%      1317.000000      13.000000       0.000000           0.000000
# 50%      1630.000000      17.000000       0.000000           0.000000
# 75%      1906.000000      22.000000       0.000000           0.000000
# max      2359.000000      26.000000       0.000000           0.000000

# %% [markdown]
# **Data Modifications**

# %%
from datetime import datetime,timedelta

# %%
start_date = pd.to_datetime('2020-01-01')

# %%
start_date
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
TRANSACTION_RAW.head(20)
# Out:
#     HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0            2375  26984851472    1     1004906         1         1.39
# 1            2375  26984851472    1     1033142         1         0.82
# 2            2375  26984851472    1     1036325         1         0.99
# 3            2375  26984851472    1     1082185         1         1.21
# 4            2375  26984851472    1     8160430         1         1.50
# 5            2375  26984851516    1      826249         2         1.98
# 6            2375  26984851516    1     1043142         1         1.57
# 7            2375  26984851516    1     1085983         1         2.99
# 8            2375  26984851516    1     1102651         1         1.89
# 9            2375  26984851516    1     6423775         1         2.00
# 10           2375  26984851516    1     9487839         1         2.00
# 11           1364  26984896261    1      842930         1         2.19
# 12           1364  26984896261    1      897044         1         2.99
# 13           1364  26984896261    1      920955         1         3.09
# 14           1364  26984896261    1      937406         1         2.50
# 15           1364  26984896261    1      981760         1         0.60
# 16           1130  26984905972    1      833715         2         0.34
# 17           1130  26984905972    1      866950         2         0.34
# 18           1130  26984905972    1     1022843         2         0.34
# 19           1130  26984905972    1     1048462         1         1.19
#
#     STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0        364        -0.60        1631        1            0                  0
# 1        364         0.00        1631        1            0                  0
# 2        364        -0.30        1631        1            0                  0
# 3        364         0.00        1631        1            0                  0
# 4        364        -0.39        1631        1            0                  0
# 5        364        -0.60        1642        1            0                  0
# 6        364        -0.68        1642        1            0                  0
# 7        364        -0.40        1642        1            0                  0
# 8        364         0.00        1642        1            0                  0
# 9        364        -0.79        1642        1            0                  0
# 10       364        -0.79        1642        1            0                  0
# 11     31742         0.00        1520        1            0                  0
# 12     31742        -0.40        1520        1            0                  0
# 13     31742         0.00        1520        1            0                  0
# 14     31742        -0.99        1520        1            0                  0
# 15     31742        -0.79        1520        1            0                  0
# 16     31642        -0.32        1340        1            0                  0
# 17     31642        -0.32        1340        1            0                  0
# 18     31642        -0.32        1340        1            0                  0
# 19     31642        -0.80        1340        1            0                  0

# %% [markdown]
# start_date_yyyy_mm_dd = start_date.strftime('%Y-%m-%d')

# %%
TRANSACTION_RAW['Date'] = start_date + pd.to_timedelta(TRANSACTION_RAW['DAY'],unit='D')

# %%
TRANSACTION_RAW['Date'].head(20)
# Out:
# 0    2020-01-02
# 1    2020-01-02
# 2    2020-01-02
# 3    2020-01-02
# 4    2020-01-02
# 5    2020-01-02
# 6    2020-01-02
# 7    2020-01-02
# 8    2020-01-02
# 9    2020-01-02
# 10   2020-01-02
# 11   2020-01-02
# 12   2020-01-02
# 13   2020-01-02
# 14   2020-01-02
# 15   2020-01-02
# 16   2020-01-02
# 17   2020-01-02
# 18   2020-01-02
# 19   2020-01-02
# Name: Date, dtype: datetime64[ns]

# %%
CAMPAIGN_DESC_RAW['Start_date']= start_date + pd.to_timedelta(CAMPAIGN_DESC_RAW['START_DAY'],unit='D')

# %%
CAMPAIGN_DESC_RAW['End_date']=start_date + pd.to_timedelta(CAMPAIGN_DESC_RAW['END_DAY'],unit='D')

# %%
CAMPAIGN_DESC_RAW.head(10)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date
# 0       TypeB        24        659      719 2021-10-21 2021-12-20
# 1       TypeC        15        547      708 2021-07-01 2021-12-09
# 2       TypeB        25        659      691 2021-10-21 2021-11-22
# 3       TypeC        20        615      685 2021-09-07 2021-11-16
# 4       TypeB        23        646      684 2021-10-08 2021-11-15
# 5       TypeB        21        624      656 2021-09-16 2021-10-18
# 6       TypeB        22        624      656 2021-09-16 2021-10-18
# 7       TypeA        18        587      642 2021-08-10 2021-10-04
# 8       TypeB        19        603      635 2021-08-26 2021-09-27
# 9       TypeB        17        575      607 2021-07-29 2021-08-30

# %%
CAMPAIGN_DESC_RAW['Campaign_Duration'] = CAMPAIGN_DESC_RAW['END_DAY'] - CAMPAIGN_DESC_RAW['START_DAY']

# %%
CAMPAIGN_DESC_RAW.head(20)
# Out:
#    DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0        TypeB        24        659      719 2021-10-21 2021-12-20
# 1        TypeC        15        547      708 2021-07-01 2021-12-09
# 2        TypeB        25        659      691 2021-10-21 2021-11-22
# 3        TypeC        20        615      685 2021-09-07 2021-11-16
# 4        TypeB        23        646      684 2021-10-08 2021-11-15
# 5        TypeB        21        624      656 2021-09-16 2021-10-18
# 6        TypeB        22        624      656 2021-09-16 2021-10-18
# 7        TypeA        18        587      642 2021-08-10 2021-10-04
# 8        TypeB        19        603      635 2021-08-26 2021-09-27
# 9        TypeB        17        575      607 2021-07-29 2021-08-30
# 10       TypeC        14        531      596 2021-06-15 2021-08-19
# 11       TypeB        16        561      593 2021-07-15 2021-08-16
# 12       TypeA        13        504      551 2021-05-19 2021-07-05
# 13       TypeB        11        477      523 2021-04-22 2021-06-07
# 14       TypeB        12        477      509 2021-04-22 2021-05-24
# 15       TypeB        10        463      495 2021-04-08 2021-05-10
# 16       TypeB         9        435      467 2021-03-11 2021-04-12
# 17       TypeA         8        412      460 2021-02-16 2021-04-05
# 18       TypeB         7        398      432 2021-02-02 2021-03-08
# 19       TypeC         6        393      425 2021-01-28 2021-03-01
#
#     Campaign_Duration
# 0                  60
# 1                 161
# 2                  32
# 3                  70
# 4                  38
# 5                  32
# 6                  32
# 7                  55
# 8                  32
# 9                  32
# 10                 65
# 11                 32
# 12                 47
# 13                 46
# 14                 32
# 15                 32
# 16                 32
# 17                 48
# 18                 34
# 19                 32

# %%
COUPON_REDEMPT_RAW['Date'] = start_date + pd.to_timedelta(COUPON_REDEMPT_RAW['DAY'],unit='D')

# %%
COUPON_REDEMPT_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY  DAY   COUPON_UPC  CAMPAIGN       Date
# 0              1  421  10000085364         8 2021-02-25
# 1              1  421  51700010076         8 2021-02-25
# 2              1  427  54200000033         8 2021-03-03
# 3              1  597  10000085476        18 2021-08-20
# 4              1  597  54200029176        18 2021-08-20
# 5              8  422  53600000078         8 2021-02-26
# 6             13  396  53700048182         5 2021-01-31
# 7             13  424  10000085364         8 2021-02-28
# 8             13  434  53600000078         8 2021-03-10
# 9             13  447  52370020076         8 2021-03-23

# %%
TRANSACTION_RAW['Date'].max()
# Out:
# Timestamp('2020-06-25 00:00:00')

# %%
CAMPAIGN_DESC_RAW['End_date'].max()
# Out:
# Timestamp('2021-12-20 00:00:00')

# %%
COUPON_REDEMPT_RAW['Date'].max()
# Out:
# Timestamp('2021-12-05 00:00:00')

# %% [markdown]
# **Understanding the dataset**

# %%
demographic_RAW.shape
# Out:
# (2500, 8)

# %%
demographic_RAW.columns
# Out:
# Index(['AGE_DESC', 'MARITAL_STATUS_CODE', 'INCOME_DESC', 'HOMEOWNER_DESC',
#        'HH_COMP_DESC', 'HOUSEHOLD_SIZE_DESC', 'KID_CATEGORY_DESC',
#        'HOUSEHOLD_KEY'],
#       dtype='object')

# %%
demographic_RAW.isnull().sum()
# Out:
# AGE_DESC               0
# MARITAL_STATUS_CODE    0
# INCOME_DESC            0
# HOMEOWNER_DESC         0
# HH_COMP_DESC           0
# HOUSEHOLD_SIZE_DESC    0
# KID_CATEGORY_DESC      0
# HOUSEHOLD_KEY          0
# dtype: int64

# %%
demographic_RAW.dtypes
# Out:
# AGE_DESC               object
# MARITAL_STATUS_CODE    object
# INCOME_DESC            object
# HOMEOWNER_DESC         object
# HH_COMP_DESC           object
# HOUSEHOLD_SIZE_DESC    object
# KID_CATEGORY_DESC      object
# HOUSEHOLD_KEY           int16
# dtype: object

# %%
demographic_RAW['AGE_DESC'].value_counts()
# Out:
# AGE_DESC
# 45-54    901
# 35-44    594
# 25-34    445
# 65+      230
# 55-64    187
# 19-24    143
# Name: count, dtype: int64

# %%
demographic_RAW['HOUSEHOLD_SIZE_DESC'].value_counts()
# Out:
# HOUSEHOLD_SIZE_DESC
# 2     1004
# 1      783
# 3      338
# 5+     206
# 4      169
# Name: count, dtype: int64

# %%
CAMPAIGN_DESC_RAW.shape
# Out:
# (30, 7)

# %%
CAMPAIGN_DESC_RAW.isnull().sum()
# Out:
# DESCRIPTION          0
# CAMPAIGN             0
# START_DAY            0
# END_DAY              0
# Start_date           0
# End_date             0
# Campaign_Duration    0
# dtype: int64

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# dtype: object

# %%
## CAMPAIGN_DESC_RAW['durations_days']=CAMPAIGN_DESC_RAW['End_date'] - CAMPAIGN_DESC_RAW['Start_date']

# %%
CAMPAIGN_DESC_RAW.head(4)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0       TypeB        24        659      719 2021-10-21 2021-12-20
# 1       TypeC        15        547      708 2021-07-01 2021-12-09
# 2       TypeB        25        659      691 2021-10-21 2021-11-22
# 3       TypeC        20        615      685 2021-09-07 2021-11-16
#
#    Campaign_Duration
# 0                 60
# 1                161
# 2                 32
# 3                 70

# %%
CAMPAIGN_DESC_RAW['Campaign_Duration'].mean()
# Out:
# 46.6

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# dtype: object

# %% [markdown]
# **The Average Campaign Duration is 46.6 days**

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='CAMPAIGN',y='Campaign_Duration',data = CAMPAIGN_DESC_RAW)
# Out:
# <Axes: xlabel='CAMPAIGN', ylabel='Campaign_Duration'>

# %% [markdown]
# **Campaign 15 Lasted more than 160 days**

# %%
CAMPAIGN_DESC_RAW.groupby('DESCRIPTION').aggregate({'CAMPAIGN':'count','Campaign_Duration':'mean'})
# Out:
#              CAMPAIGN  Campaign_Duration
# DESCRIPTION
# TypeA               5          47.200000
# TypeB              19          37.631579
# TypeC               6          74.500000

# %% [markdown]
# **There have been 19 type B campaigns, whose average length was 38 days. In comparison, there has been 6 type C campaigns of 75 days on average.**

# %%
CAMPAIGN_DESC_RAW['Start_month'] = CAMPAIGN_DESC_RAW['Start_date'].dt.strftime('%m')

# %%
CAMPAIGN_DESC_RAW['End_month'] = CAMPAIGN_DESC_RAW['End_date'].dt.strftime('%m')

# %%
CAMPAIGN_DESC_RAW['Start_Year'] = CAMPAIGN_DESC_RAW['Start_date'].dt.strftime('%Y')

# %%
CAMPAIGN_DESC_RAW['End_Year'] = CAMPAIGN_DESC_RAW['End_date'].dt.strftime('%Y')

# %%
CAMPAIGN_DESC_RAW.head(4)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0       TypeB        24        659      719 2021-10-21 2021-12-20
# 1       TypeC        15        547      708 2021-07-01 2021-12-09
# 2       TypeB        25        659      691 2021-10-21 2021-11-22
# 3       TypeC        20        615      685 2021-09-07 2021-11-16
#
#    Campaign_Duration Start_month End_month Start_Year End_Year
# 0                 60          10        12       2021     2021
# 1                161          07        12       2021     2021
# 2                 32          10        11       2021     2021
# 3                 70          09        11       2021     2021

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# Start_month                  object
# End_month                    object
# Start_Year                   object
# End_Year                     object
# dtype: object

# %%
CAMPAIGN_RAW.shape
# Out:
# (7208, 3)

# %%
CAMPAIGN_RAW.columns
# Out:
# Index(['DESCRIPTION', 'HOUSEHOLD_KEY', 'CAMPAIGN'], dtype='object')

# %%
CAMPAIGN_RAW.isnull().sum()
# Out:
# DESCRIPTION      0
# HOUSEHOLD_KEY    0
# CAMPAIGN         0
# dtype: int64

# %%
CAMPAIGN_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 1584

# %%
TRANSACTION_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 2494

# %% [markdown]
# **There are 1584 households have participed to the campaign, leaving 916 households who never participated to any campaign.**

# %%
CAMPAIGN_RAW.dtypes
# Out:
# DESCRIPTION      object
# HOUSEHOLD_KEY     int16
# CAMPAIGN           int8
# dtype: object

# %%
CAMPAIGN_RAW.groupby('HOUSEHOLD_KEY')['CAMPAIGN'].count()
# Out:
# HOUSEHOLD_KEY
# 1       8
# 2       1
# 3       3
# 4       1
# 6       4
#        ..
# 2496    5
# 2497    3
# 2498    6
# 2499    2
# 2500    8
# Name: CAMPAIGN, Length: 1584, dtype: int64

# %%
plt.figure(figsize=(15,5))
CAMPAIGN_RAW.groupby('CAMPAIGN')['HOUSEHOLD_KEY'].count().plot.bar()
plt.ylabel('Number of Households Reached To')
# Out:
# Text(0, 0.5, 'Number of Households Reached To')

# %% [markdown]
# **In Campaing 18 maximum number of households are participated.**

# %%
COUPON_RAW.shape
# Out:
# (124548, 3)

# %%
COUPON_RAW.columns
# Out:
# Index(['COUPON_UPC', 'PRODUCT_ID', 'CAMPAIGN'], dtype='object')

# %%
COUPON_RAW['COUPON_UPC'].nunique()
# Out:
# 1135

# %%
COUPON_RAW.isnull().sum()
# Out:
# COUPON_UPC    0
# PRODUCT_ID    0
# CAMPAIGN      0
# dtype: int64

# %%
COUPON_RAW.dtypes
# Out:
# COUPON_UPC    int64
# PRODUCT_ID    int32
# CAMPAIGN       int8
# dtype: object

# %%
Coupon_Given=COUPON_RAW.groupby("CAMPAIGN").aggregate(Total_product = ('PRODUCT_ID','nunique'),
                                                    Total_Coupon_Given = ('COUPON_UPC','nunique'))

# %%
Coupon_Given.sort_values(by='Total_product',ascending=False).head(10)
# Out:
#           Total_product  Total_Coupon_Given
# CAMPAIGN
# 13                35616                 207
# 18                35513                 209
# 8                 17178                 209
# 26                 3396                 181
# 30                 3205                 181
# 22                 1917                  21
# 24                 1887                   2
# 16                 1025                  13
# 25                  826                  17
# 9                   825                  18

# %%
Coupon_Given.head(10)
# Out:
#           Total_product  Total_Coupon_Given
# CAMPAIGN
# 1                   383                  11
# 2                   301                  16
# 3                   506                  34
# 4                   200                  12
# 5                   443                  11
# 6                    18                   1
# 7                   259                   8
# 8                 17178                 209
# 9                   825                  18
# 10                  393                  14

# %%
Coupon_Given = Coupon_Given.merge(right = CAMPAIGN_DESC_RAW,on='CAMPAIGN',how='left')

# %%
Coupon_Given.head(10)
# Out:
#    CAMPAIGN  Total_product  Total_Coupon_Given DESCRIPTION  START_DAY  \
# 0         1            383                  11       TypeB        346
# 1         2            301                  16       TypeB        351
# 2         3            506                  34       TypeC        356
# 3         4            200                  12       TypeB        372
# 4         5            443                  11       TypeB        377
# 5         6             18                   1       TypeC        393
# 6         7            259                   8       TypeB        398
# 7         8          17178                 209       TypeA        412
# 8         9            825                  18       TypeB        435
# 9        10            393                  14       TypeB        463
#
#    END_DAY Start_date   End_date  Campaign_Duration Start_month End_month  \
# 0      383 2020-12-12 2021-01-18                 37          12        01
# 1      383 2020-12-17 2021-01-18                 32          12        01
# 2      412 2020-12-22 2021-02-16                 56          12        02
# 3      404 2021-01-07 2021-02-08                 32          01        02
# 4      411 2021-01-12 2021-02-15                 34          01        02
# 5      425 2021-01-28 2021-03-01                 32          01        03
# 6      432 2021-02-02 2021-03-08                 34          02        03
# 7      460 2021-02-16 2021-04-05                 48          02        04
# 8      467 2021-03-11 2021-04-12                 32          03        04
# 9      495 2021-04-08 2021-05-10                 32          04        05
#
#   Start_Year End_Year
# 0       2020     2021
# 1       2020     2021
# 2       2020     2021
# 3       2021     2021
# 4       2021     2021
# 5       2021     2021
# 6       2021     2021
# 7       2021     2021
# 8       2021     2021
# 9       2021     2021

# %%
Coupon_Given.columns
# Out:
# Index(['CAMPAIGN', 'Total_product', 'Total_Coupon_Given', 'DESCRIPTION',
#        'START_DAY', 'END_DAY', 'Start_date', 'End_date', 'Campaign_Duration',
#        'Start_month', 'End_month', 'Start_Year', 'End_Year'],
#       dtype='object')

# %%
Coupon_Given.loc[:,('CAMPAIGN','Total_product','Total_Coupon_Given','Start_Year','End_Year','Start_month','End_month','DESCRIPTION','Campaign_Duration')].sort_values(by='Total_product',
                    ascending=False).head(10)
# Out:
#     CAMPAIGN  Total_product  Total_Coupon_Given Start_Year End_Year  \
# 12        13          35616                 207       2021     2021
# 17        18          35513                 209       2021     2021
# 7          8          17178                 209       2021     2021
# 25        26           3396                 181       2020     2020
# 29        30           3205                 181       2020     2021
# 21        22           1917                  21       2021     2021
# 23        24           1887                   2       2021     2021
# 15        16           1025                  13       2021     2021
# 24        25            826                  17       2021     2021
# 8          9            825                  18       2021     2021
#
#    Start_month End_month DESCRIPTION  Campaign_Duration
# 12          05        07       TypeA                 47
# 17          08        10       TypeA                 55
# 7           02        04       TypeA                 48
# 25          08        09       TypeA                 40
# 29          11        01       TypeA                 46
# 21          09        10       TypeB                 32
# 23          10        12       TypeB                 60
# 15          07        08       TypeB                 32
# 24          10        11       TypeB                 32
# 8           03        04       TypeB                 32

# %%
COUPON_RAW.head()
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25

# %%
PRODUCT_RAW.head()
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %% [markdown]
# **campaign 13,18,8 are the one with most product in them.**

# %%
coupon_product = COUPON_RAW.merge(right=PRODUCT_RAW,on='PRODUCT_ID',how='left')

# %%
coupon_product.head(5)
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN  MANUFACTURER DEPARTMENT     BRAND  \
# 0  10000089061       27160         4            69    GROCERY   Private
# 1  10000089064       27754         9            69    GROCERY   Private
# 2  10000089073       28897        12            69    GROCERY   Private
# 3  51800009050       28919        28           236    GROCERY  National
# 4  52100000076       28929        25           317    GROCERY  National
#
#              COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 0            SHORTENING/OIL             VEGETABLE/SALAD OIL
# 1    FRZN VEGETABLE/VEG DSH  FRZN BAGGED VEGETABLES - PLAIN
# 2                      EGGS                  EGGS - X-LARGE
# 3  REFRGRATD DOUGH PRODUCTS       REFRIGERATED COOKIES-CHUB
# 4                    CHEESE                   STRING CHEESE
#
#   CURR_SIZE_OF_PRODUCT
# 0                48 OZ
# 1                16 OZ
# 2           A D   1 DZ
# 3              16.5 OZ
# 4           AB    8 OZ

# %%
coupon_product.isnull().sum()
# Out:
# COUPON_UPC              0
# PRODUCT_ID              0
# CAMPAIGN                0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %% [markdown]
# **Top 10 product on which the Coupon has been applied**

# %%
coupon_product['COMMODITY_DESC'].value_counts().head(10)
# Out:
# COMMODITY_DESC
# HAIR CARE PRODUCTS        6261
# MAKEUP AND TREATMENT      5585
# FRZN MEAT/MEAT DINNERS    4893
# FROZEN PIZZA              3658
# BEEF                      3314
# ICE CREAM/MILK/SHERBTS    3257
# CHEESE                    3146
# YOGURT                    2460
# ORAL HYGIENE PRODUCTS     2437
# LUNCHMEAT                 2425
# Name: count, dtype: int64

# %% [markdown]
# **Most prominent products among coupons created are bathroom products such as hair care and makeup.**

# %%
COUPON_REDEMPT_RAW.shape
# Out:
# (2318, 5)

# %%
COUPON_REDEMPT_RAW.columns
# Out:
# Index(['HOUSEHOLD_KEY', 'DAY', 'COUPON_UPC', 'CAMPAIGN', 'Date'], dtype='object')

# %%
COUPON_REDEMPT_RAW['COUPON_UPC'].nunique()
# Out:
# 556

# %% [markdown]
# **Only 556 Coupon has been used out of 1135**

# %%
COUPON_REDEMPT_RAW.groupby('CAMPAIGN').agg(total_coupon_reedm=('COUPON_UPC','nunique')).sort_values(by='total_coupon_reedm',ascending=False).plot.bar()
# Out:
# <Axes: xlabel='CAMPAIGN'>

# %%
Coupon_redeem = COUPON_REDEMPT_RAW.groupby('CAMPAIGN').agg(total_coupon_reedm=('COUPON_UPC','nunique'))

# %%
Coupon_redeem.sort_values(by = 'total_coupon_reedm',ascending=False)
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 13                       129
# 18                       121
# 8                        105
# 26                        53
# 30                        41
# 29                        17
# 23                        16
# 25                        15
# 20                        15
# 9                         14
# 14                        14
# 17                        13
# 22                        12
# 12                        11
# 16                        10
# 19                         9
# 10                         7
# 11                         6
# 4                          6
# 21                         5
# 7                          5
# 5                          5
# 2                          4
# 15                         2
# 24                         2
# 3                          2
# 6                          1
# 27                         1
# 28                         1
# 1                          1

# %%
Coupon_Given.head()
# Out:
#    CAMPAIGN  Total_product  Total_Coupon_Given DESCRIPTION  START_DAY  \
# 0         1            383                  11       TypeB        346
# 1         2            301                  16       TypeB        351
# 2         3            506                  34       TypeC        356
# 3         4            200                  12       TypeB        372
# 4         5            443                  11       TypeB        377
#
#    END_DAY Start_date   End_date  Campaign_Duration Start_month End_month  \
# 0      383 2020-12-12 2021-01-18                 37          12        01
# 1      383 2020-12-17 2021-01-18                 32          12        01
# 2      412 2020-12-22 2021-02-16                 56          12        02
# 3      404 2021-01-07 2021-02-08                 32          01        02
# 4      411 2021-01-12 2021-02-15                 34          01        02
#
#   Start_Year End_Year
# 0       2020     2021
# 1       2020     2021
# 2       2020     2021
# 3       2021     2021
# 4       2021     2021

# %%
Coupon_redeem.head(3)
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 1                          1
# 2                          4
# 3                          2

# %%
Coupon_redeem = Coupon_redeem.merge(right = Coupon_Given,on='CAMPAIGN',how='left')

# %%
Coupon_redeem.head()
# Out:
#    CAMPAIGN  total_coupon_reedm  Total_product  Total_Coupon_Given  \
# 0         1                   1            383                  11
# 1         2                   4            301                  16
# 2         3                   2            506                  34
# 3         4                   6            200                  12
# 4         5                   5            443                  11
#
#   DESCRIPTION  START_DAY  END_DAY Start_date   End_date  Campaign_Duration  \
# 0       TypeB        346      383 2020-12-12 2021-01-18                 37
# 1       TypeB        351      383 2020-12-17 2021-01-18                 32
# 2       TypeC        356      412 2020-12-22 2021-02-16                 56
# 3       TypeB        372      404 2021-01-07 2021-02-08                 32
# 4       TypeB        377      411 2021-01-12 2021-02-15                 34
#
#   Start_month End_month Start_Year End_Year
# 0          12        01       2020     2021
# 1          12        01       2020     2021
# 2          12        02       2020     2021
# 3          01        02       2021     2021
# 4          01        02       2021     2021

# %%
Coupon_redeem['Coupon_redeem_rate']=(Coupon_redeem['total_coupon_reedm']/Coupon_redeem['Total_Coupon_Given'])*100

# %%
Coupon_redeem.head().sort_values(by = 'Coupon_redeem_rate',ascending = False)
# Out:
#    CAMPAIGN  total_coupon_reedm  Total_product  Total_Coupon_Given  \
# 3         4                   6            200                  12
# 4         5                   5            443                  11
# 1         2                   4            301                  16
# 0         1                   1            383                  11
# 2         3                   2            506                  34
#
#   DESCRIPTION  START_DAY  END_DAY Start_date   End_date  Campaign_Duration  \
# 3       TypeB        372      404 2021-01-07 2021-02-08                 32
# 4       TypeB        377      411 2021-01-12 2021-02-15                 34
# 1       TypeB        351      383 2020-12-17 2021-01-18                 32
# 0       TypeB        346      383 2020-12-12 2021-01-18                 37
# 2       TypeC        356      412 2020-12-22 2021-02-16                 56
#
#   Start_month End_month Start_Year End_Year  Coupon_redeem_rate
# 3          01        02       2021     2021           50.000000
# 4          01        02       2021     2021           45.454545
# 1          12        01       2020     2021           25.000000
# 0          12        01       2020     2021            9.090909
# 2          12        02       2020     2021            5.882353

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='CAMPAIGN',y='Coupon_redeem_rate',data=Coupon_redeem)
# Out:
# <Axes: xlabel='CAMPAIGN', ylabel='Coupon_redeem_rate'>

# %%
TRANSACTION_RAW.shape
# Out:
# (450416, 13)

# %%
TRANSACTION_RAW.columns
# Out:
# Index(['HOUSEHOLD_KEY', 'BASKET_ID', 'DAY', 'PRODUCT_ID', 'QUANTITY',
#        'SALES_VALUE', 'STORE_ID', 'RETAIL_DISC', 'TRANS_TIME', 'WEEK_NO',
#        'COUPON_DISC', 'COUPON_MATCH_DISC', 'Date'],
#       dtype='object')

# %%
TRANSACTION_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# TRANS_TIME           0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# Date                 0
# dtype: int64

# %%
TRANSACTION_RAW['BASKET_ID'].count()
# Out:
# 450416

# %%
TRANSACTION_RAW['BASKET_ID'].nunique()
# Out:
# 50479

# %%
TRANSACTION_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 2494

# %%
trnx_bucket =TRANSACTION_RAW.groupby('BASKET_ID').aggregate({'SALES_VALUE':'sum','COUPON_DISC':'sum','COUPON_MATCH_DISC':'sum'})

# %%
trnx_bucket.head()
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC
# BASKET_ID
# 26984851472         5.91            0                  0
# 26984851516        12.43            0                  0
# 26984896261        11.37            0                  0
# 26984905972         2.55            0                  0
# 26984945254         3.53            0                  0

# %%
trnx_bucket['Use_coupon'] = trnx_bucket['COUPON_DISC']!=0

# %%
trnx_bucket['Use_coupon'].value_counts()
# Out:
# Use_coupon
# False    47892
# True      2587
# Name: count, dtype: int64

# %%
trnx_bucket.sort_values('SALES_VALUE',ascending=False).head(10)
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC  Use_coupon
# BASKET_ID
# 27534431747       465.70           -3                 -1        True
# 27798435271       463.17           -2                 -2        True
# 27093315740       400.79            0                  0       False
# 28941937397       400.56           -1                  0        True
# 28210676830       391.05            0                  0       False
# 27950470466       376.38           -2                  0        True
# 29034966796       369.48            0                  0       False
# 28919755135       368.95            0                  0       False
# 28675556859       365.86           -3                  0        True
# 29221810662       358.98            0                  0       False

# %%
round(trnx_bucket['SALES_VALUE'].mean(),2)
# Out:
# 26.93

# %% [markdown]
# The average basket value is $29.14

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x=trnx_bucket['SALES_VALUE'])
plt.title('Basket value boxplot', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Basket value boxplot')

# %%
trnx_bucket.groupby('Use_coupon').aggregate( sales_mean=('SALES_VALUE','mean'),
                                             COUPON_DISC_mean =('COUPON_DISC','mean'),
                                             COUPON_MATCH_DISC=('COUPON_MATCH_DISC','mean'),
                                             No_coupon  =('SALES_VALUE','count'))
# Out:
#             sales_mean  COUPON_DISC_mean  COUPON_MATCH_DISC  No_coupon
# Use_coupon
# False        25.009980          0.000000           0.000000      47892
# True         62.533348         -2.587167          -0.334364       2587

# %% [markdown]
# The average basket value without a coupon is $26.79.
#
# The average basket value with a coupon is $68.21.
#
# The average discount generated by coupons is $2.98.

# %% [markdown]
# **It shows that customeer purchase more product when coupon is given to them**

# %%
trnx_desc = TRANSACTION_RAW.merge(right= trnx_bucket,on='BASKET_ID',how='left')

# %%
trnx_desc.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2375  26984851472    1     1004906         1           1.39
# 1           2375  26984851472    1     1033142         1           0.82
# 2           2375  26984851472    1     1036325         1           0.99
# 3           2375  26984851472    1     1082185         1           1.21
# 4           2375  26984851472    1     8160430         1           1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC_x  \
# 0       364        -0.60        1631        1              0
# 1       364         0.00        1631        1              0
# 2       364        -0.30        1631        1              0
# 3       364         0.00        1631        1              0
# 4       364        -0.39        1631        1              0
#
#    COUPON_MATCH_DISC_x       Date  SALES_VALUE_y  COUPON_DISC_y  \
# 0                    0 2020-01-02           5.91              0
# 1                    0 2020-01-02           5.91              0
# 2                    0 2020-01-02           5.91              0
# 3                    0 2020-01-02           5.91              0
# 4                    0 2020-01-02           5.91              0
#
#    COUPON_MATCH_DISC_y  Use_coupon
# 0                    0       False
# 1                    0       False
# 2                    0       False
# 3                    0       False
# 4                    0       False

# %%
trnx_desc= trnx_desc.merge(right=PRODUCT_RAW,on='PRODUCT_ID',how='left')

# %%
trnx_desc.head(3)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2375  26984851472    1     1004906         1           1.39
# 1           2375  26984851472    1     1033142         1           0.82
# 2           2375  26984851472    1     1036325         1           0.99
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  ...  SALES_VALUE_y  \
# 0       364         -0.6        1631        1  ...           5.91
# 1       364          0.0        1631        1  ...           5.91
# 2       364         -0.3        1631        1  ...           5.91
#
#    COUPON_DISC_y COUPON_MATCH_DISC_y  Use_coupon  MANUFACTURER  DEPARTMENT  \
# 0              0                   0       False            69     PRODUCE
# 1              0                   0       False             2     PRODUCE
# 2              0                   0       False            69     PRODUCE
#
#       BRAND           COMMODITY_DESC          SUB_COMMODITY_DESC  \
# 0   Private                 POTATOES  POTATOES RUSSET (BULK&BAG)
# 1  National                   ONIONS     ONIONS SWEET (BULK&BAG)
# 2   Private  VEGETABLES - ALL OTHERS                      CELERY
#
#   CURR_SIZE_OF_PRODUCT
# 0                 5 LB
# 1                40 LB
# 2
#
# [3 rows x 23 columns]

# %%
trnx_desc.drop(['SALES_VALUE_y','COUPON_DISC_y','COUPON_MATCH_DISC_y'],axis=1,inplace=True)

# %%
trnx_desc.head(10)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2375  26984851472    1     1004906         1           1.39
# 1           2375  26984851472    1     1033142         1           0.82
# 2           2375  26984851472    1     1036325         1           0.99
# 3           2375  26984851472    1     1082185         1           1.21
# 4           2375  26984851472    1     8160430         1           1.50
# 5           2375  26984851516    1      826249         2           1.98
# 6           2375  26984851516    1     1043142         1           1.57
# 7           2375  26984851516    1     1085983         1           2.99
# 8           2375  26984851516    1     1102651         1           1.89
# 9           2375  26984851516    1     6423775         1           2.00
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC_x  \
# 0       364        -0.60        1631        1              0
# 1       364         0.00        1631        1              0
# 2       364        -0.30        1631        1              0
# 3       364         0.00        1631        1              0
# 4       364        -0.39        1631        1              0
# 5       364        -0.60        1642        1              0
# 6       364        -0.68        1642        1              0
# 7       364        -0.40        1642        1              0
# 8       364         0.00        1642        1              0
# 9       364        -0.79        1642        1              0
#
#    COUPON_MATCH_DISC_x       Date  Use_coupon  MANUFACTURER DEPARTMENT  \
# 0                    0 2020-01-02       False            69    PRODUCE
# 1                    0 2020-01-02       False             2    PRODUCE
# 2                    0 2020-01-02       False            69    PRODUCE
# 3                    0 2020-01-02       False             2    PRODUCE
# 4                    0 2020-01-02       False            69    PRODUCE
# 5                    0 2020-01-02       False            69    GROCERY
# 6                    0 2020-01-02       False           321    DRUG GM
# 7                    0 2020-01-02       False           586    GROCERY
# 8                    0 2020-01-02       False          1266    GROCERY
# 9                    0 2020-01-02       False           586    GROCERY
#
#       BRAND               COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0   Private                     POTATOES   POTATOES RUSSET (BULK&BAG)
# 1  National                       ONIONS      ONIONS SWEET (BULK&BAG)
# 2   Private      VEGETABLES - ALL OTHERS                       CELERY
# 3  National               TROPICAL FRUIT                      BANANAS
# 4   Private  ORGANICS FRUIT & VEGETABLES              ORGANIC CARROTS
# 5   Private       BAKED BREAD/BUNS/ROLLS               HAMBURGER BUNS
# 6  National              BROOMS AND MOPS      SPONGES: BATH HOUSEHOLD
# 7  National                COOKIES/CONES  TRAY PACK/CHOC CHIP COOKIES
# 8  National           PNT BTR/JELLY/JAMS                PEANUT BUTTER
# 9  National                COOKIES/CONES              GRAHAM CRACKERS
#
#   CURR_SIZE_OF_PRODUCT
# 0                 5 LB
# 1                40 LB
# 2
# 3                40 LB
# 4                 1 LB
# 5                12 OZ
# 6
# 7                18 OZ
# 8                12 OZ
# 9                11 OZ

# %%
COMMODITY_Coupon = trnx_desc.groupby('COMMODITY_DESC').aggregate(total_quantity=('QUANTITY','count'),
                                             Use_coupon=('Use_coupon','sum'),
                                             Coupon=('COUPON_DISC_x','sum'))

# %%
COMMODITY_Coupon.head(10)
# Out:
#                       total_quantity  Use_coupon  Coupon
# COMMODITY_DESC
#                                 1303         872   -1396
# (CORP USE ONLY)                   12           0       0
# ADULT INCONTINENCE                74           3      -1
# AIR CARE                         928         193    -124
# ANALGESICS                       681          89      -3
# ANTACIDS                         307          36      -7
# APPAREL                          138          11       0
# APPLES                          2001         287       0
# AUDIO/VIDEO PRODUCTS             149          16     -40
# AUTOMOTIVE PRODUCTS              216          25      -6

# %%
COMMODITY_Coupon['Coupon%']=round((COMMODITY_Coupon['Use_coupon']/COMMODITY_Coupon['total_quantity'])*100,2)

# %%
COMMODITY_Coupon.sort_values('Coupon%',ascending=False).head(30)
# Out:
#                                 total_quantity  Use_coupon  Coupon  Coupon%
# COMMODITY_DESC
# NATURAL VITAMINS                             1           1      -5   100.00
#                                           1303         872   -1396    66.92
# VALENTINE                                    5           2       0    40.00
# BABY FOODS                                3664        1114     -38    30.40
# RW FRESH PROCESSED MEAT                      7           2       0    28.57
# DIAPERS & DISPOSABLES                      864         231    -215    26.74
# BABY HBC                                   817         181     -82    22.15
# AIR CARE                                   928         193    -124    20.80
# FRZN BREAKFAST FOODS                      1743         347     -61    19.91
# CAT LITTER                                 531         104     -11    19.59
# FACIAL TISS/DNR NAPKIN                    1237         242     -29    19.56
# GLASSWARE & DINNERWARE                      36           7       0    19.44
# LAUNDRY ADDITIVES                          921         176     -25    19.11
# FRUIT - SHELF STABLE                      3267         611     -19    18.70
# VITAMINS                                   334          61     -18    18.26
# HOUSEHOLD CLEANG NEEDS                    1962         355     -96    18.09
# FD WRAPS/BAGS/TRSH BG                     2358         416     -48    17.64
# ORAL HYGIENE PRODUCTS                     1715         302    -104    17.61
# FROZEN - BOXED(GROCERY)                    127          22     -14    17.32
# FROZEN BREAD/DOUGH                        1241         214     -62    17.24
# DISHWASH DETERGENTS                       1198         206     -43    17.20
# PICKLE/RELISH/PKLD VEG                    1350         232     -69    17.19
# HAIR CARE PRODUCTS                        2119         363     -79    17.13
# DOG FOODS                                 1923         326     -64    16.95
# TEAS                                       730         123     -19    16.85
# RICE CAKES                                 250          42       0    16.80
# CEREAL/BREAKFAST                           304          51     -10    16.78
# PAPER TOWELS                              1775         296     -18    16.68
# BATH TISSUES                              2410         397    -125    16.47
# CONVENIENT BRKFST/WHLSM SNACKS            3878         638     -90    16.45

# %% [markdown]
# **While the most prominents products for which coupons are created are haircare and makeup products, coupons are mostly used on drinks, cigarettes, diapers, etc. Bathroom products are not even among the top 10**

# %%
TRANSACTION_RAW.groupby(['HOUSEHOLD_KEY','WEEK_NO','DAY']).aggregate({'SALES_VALUE':'sum','RETAIL_DISC':'sum',
                                                                  'COUPON_DISC' :'sum','COUPON_MATCH_DISC':'sum'})
# Out:
#                            SALES_VALUE  RETAIL_DISC  COUPON_DISC  \
# HOUSEHOLD_KEY WEEK_NO DAY
# 1             8       51         78.66       -16.54           -1
#               10      67         41.10        -8.59            0
#               13      88         26.90        -6.72            0
#               14      94         63.43       -11.08           -2
#               15      101        53.45       -16.42            0
# ...                                ...          ...          ...
# 2500          21      145        50.23        -2.02           -3
#               22      150        55.03        -2.17            0
#               26      174       110.30       -49.05           -1
#                       175        10.59         0.00           -2
#                       176        20.26        -2.51            0
#
#                            COUPON_MATCH_DISC
# HOUSEHOLD_KEY WEEK_NO DAY
# 1             8       51                   0
#               10      67                   0
#               13      88                   0
#               14      94                  -1
#               15      101                  0
# ...                                      ...
# 2500          21      145                  0
#               22      150                  0
#               26      174                  0
#                       175                  0
#                       176                  0
#
# [40506 rows x 4 columns]

# %%
TRANSACTION_RAW.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0       364        -0.60        1631        1            0                  0
# 1       364         0.00        1631        1            0                  0
# 2       364        -0.30        1631        1            0                  0
# 3       364         0.00        1631        1            0                  0
# 4       364        -0.39        1631        1            0                  0
#
#         Date
# 0 2020-01-02
# 1 2020-01-02
# 2 2020-01-02
# 3 2020-01-02
# 4 2020-01-02

# %%
TRANSACTION_RAW.groupby(TRANSACTION_RAW['Date'].dt.year).aggregate({'SALES_VALUE':'sum','RETAIL_DISC':'sum',
                                                                   'COUPON_DISC':'sum'})
# Out:
#       SALES_VALUE  RETAIL_DISC  COUPON_DISC
# Date
# 2020   1359551.73   -248978.11        -6693

# %% [markdown]
# **Sales Value increases as Retail Discount and Coupon Discount increases**

# %% [markdown]
# **Droping the columns**

# %%
from datetime import datetime

# %%
CAMPAIGN_DESC_RAW.drop(['START_DAY','END_DAY'],axis=1,inplace=True)

# %%
CAMPAIGN_DESC_RAW.head(3)
# Out:
#   DESCRIPTION  CAMPAIGN Start_date   End_date  Campaign_Duration Start_month  \
# 0       TypeB        24 2021-10-21 2021-12-20                 60          10
# 1       TypeC        15 2021-07-01 2021-12-09                161          07
# 2       TypeB        25 2021-10-21 2021-11-22                 32          10
#
#   End_month Start_Year End_Year
# 0        12       2021     2021
# 1        12       2021     2021
# 2        11       2021     2021

# %%
CAMPAIGN_DESC_RAW['Start_date'] = pd.to_datetime(CAMPAIGN_DESC_RAW['Start_date']).apply(lambda x: x.date())

# %%
type(CAMPAIGN_DESC_RAW['Start_date'])
# Out:
# pandas.core.series.Series

# %%
CAMPAIGN_DESC_RAW['Start_date']
# Out:
# 0     2021-10-21
# 1     2021-07-01
# 2     2021-10-21
# 3     2021-09-07
# 4     2021-10-08
# 5     2021-09-16
# 6     2021-09-16
# 7     2021-08-10
# 8     2021-08-26
# 9     2021-07-29
# 10    2021-06-15
# 11    2021-07-15
# 12    2021-05-19
# 13    2021-04-22
# 14    2021-04-22
# 15    2021-04-08
# 16    2021-03-11
# 17    2021-02-16
# 18    2021-02-02
# 19    2021-01-28
# 20    2020-12-22
# 21    2021-01-12
# 22    2021-01-07
# 23    2020-12-12
# 24    2020-12-17
# 25    2020-11-19
# 26    2020-10-08
# 27    2020-09-16
# 28    2020-08-25
# 29    2020-08-12
# Name: Start_date, dtype: object

# %%
CAMPAIGN_DESC_RAW['End_date'] = pd.to_datetime(CAMPAIGN_DESC_RAW['End_date']).apply(lambda x: x.date())

# %%
type(CAMPAIGN_DESC_RAW['End_date'])
# Out:
# pandas.core.series.Series

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION          object
# CAMPAIGN               int8
# Start_date           object
# End_date             object
# Campaign_Duration     int16
# Start_month          object
# End_month            object
# Start_Year           object
# End_Year             object
# dtype: object

# %%
COUPON_REDEMPT_RAW.drop(['DAY'],axis=1,inplace=True)

# %%
COUPON_REDEMPT_RAW.head(3)
# Out:
#    HOUSEHOLD_KEY   COUPON_UPC  CAMPAIGN       Date
# 0              1  10000085364         8 2021-02-25
# 1              1  51700010076         8 2021-02-25
# 2              1  54200000033         8 2021-03-03

# %%
COUPON_REDEMPT_RAW['Date']=pd.to_datetime(COUPON_REDEMPT_RAW['Date']).apply(lambda x: x.date())

# %%
COUPON_REDEMPT_RAW.dtypes
# Out:
# HOUSEHOLD_KEY     int16
# COUPON_UPC        int64
# CAMPAIGN           int8
# Date             object
# dtype: object

# %%
TRANSACTION_RAW.drop(['DAY','WEEK_NO'],axis=1,inplace=True)

# %%
TRANSACTION_RAW.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE  STORE_ID  \
# 0           2375  26984851472     1004906         1         1.39       364
# 1           2375  26984851472     1033142         1         0.82       364
# 2           2375  26984851472     1036325         1         0.99       364
# 3           2375  26984851472     1082185         1         1.21       364
# 4           2375  26984851472     8160430         1         1.50       364
#
#    RETAIL_DISC  TRANS_TIME  COUPON_DISC  COUPON_MATCH_DISC       Date
# 0        -0.60        1631            0                  0 2020-01-02
# 1         0.00        1631            0                  0 2020-01-02
# 2        -0.30        1631            0                  0 2020-01-02
# 3         0.00        1631            0                  0 2020-01-02
# 4        -0.39        1631            0                  0 2020-01-02

# %%
TRANSACTION_RAW['Date']=pd.to_datetime(TRANSACTION_RAW['Date']).apply(lambda x: x.date())

# %%
TRANSACTION_RAW.dtypes
# Out:
# HOUSEHOLD_KEY          int16
# BASKET_ID              int64
# PRODUCT_ID             int32
# QUANTITY               int32
# SALES_VALUE          float64
# STORE_ID               int16
# RETAIL_DISC          float64
# TRANS_TIME             int16
# COUPON_DISC             int8
# COUPON_MATCH_DISC       int8
# Date                  object
# dtype: object

# %%
TRANSACTION_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE  STORE_ID  \
# 0           2375  26984851472     1004906         1         1.39       364
# 1           2375  26984851472     1033142         1         0.82       364
# 2           2375  26984851472     1036325         1         0.99       364
# 3           2375  26984851472     1082185         1         1.21       364
# 4           2375  26984851472     8160430         1         1.50       364
# 5           2375  26984851516      826249         2         1.98       364
# 6           2375  26984851516     1043142         1         1.57       364
# 7           2375  26984851516     1085983         1         2.99       364
# 8           2375  26984851516     1102651         1         1.89       364
# 9           2375  26984851516     6423775         1         2.00       364
#
#    RETAIL_DISC  TRANS_TIME  COUPON_DISC  COUPON_MATCH_DISC        Date
# 0        -0.60        1631            0                  0  2020-01-02
# 1         0.00        1631            0                  0  2020-01-02
# 2        -0.30        1631            0                  0  2020-01-02
# 3         0.00        1631            0                  0  2020-01-02
# 4        -0.39        1631            0                  0  2020-01-02
# 5        -0.60        1642            0                  0  2020-01-02
# 6        -0.68        1642            0                  0  2020-01-02
# 7        -0.40        1642            0                  0  2020-01-02
# 8         0.00        1642            0                  0  2020-01-02
# 9        -0.79        1642            0                  0  2020-01-02

# %% [markdown]
# **Now loading the table to Db**

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import snowflake.connector as snowCtx
from snowflake.connector.pandas_tools import write_pandas
import pandas as pd
import getpass

# %%
conn = snowflake.connector.connect(
        user = 'akshaysingh',
        ##password = getpass.getpass('Your Snowflake Password: ')
        password='Turtleking23!',
        account = 'HFZNEEE-XK27295',
        database='RETAIL',
        warehouse='COMPUTE_WH',
        SCHEMA='PUBLIC',
        schema ='PUBLIC'
 )

# %%
cur=conn.cursor()

# %%
cur.execute(''' CREATE OR REPLACE TABLE COUPON_REDEMPT_NEW
(HOUSEHOLD_KEY NUMBER(38,0),
COUPON_UPC NUMBER(38,0),
CAMPAIGN NUMBER(38,0),
Date Date
)''')

# %%
cur.execute('''CREATE OR REPLACE TABLE TRANSACTION_NEW
(HOUSEHOLD_KEY NUMBER(38,0),
BASKET_ID NUMBER(38,0),
PRODUCT_ID NUMBER(38,0),
QUANTITY NUMBER(38,0),
SALES_VALUE FLOAT,
STORE_ID NUMBER(38,0),
RETAIL_DISC FLOAT,
TRANS_TIME NUMBER(38,0),
COUPON_DISC FLOAT,
COUPON_MATCH_DISC FLOAT,
Date Date
)
''')

# %%
CAMPAIGN_DESC_RAW.head() ## cleaned raw dataframe
# Out:
#   DESCRIPTION  CAMPAIGN  Start_date    End_date  Campaign_Duration  \
# 0       TypeB        24  2021-10-21  2021-12-20                 60
# 1       TypeC        15  2021-07-01  2021-12-09                161
# 2       TypeB        25  2021-10-21  2021-11-22                 32
# 3       TypeC        20  2021-09-07  2021-11-16                 70
# 4       TypeB        23  2021-10-08  2021-11-15                 38
#
#   Start_month End_month Start_Year End_Year
# 0          10        12       2021     2021
# 1          07        12       2021     2021
# 2          10        11       2021     2021
# 3          09        11       2021     2021
# 4          10        11       2021     2021

# %%
cur.execute('''
CREATE OR REPLACE TABLE CAMPAIGN_DESC_NEW
(DESCRIPTION VARCHAR(10),
CAMPAIGN NUMBER(38,0),
Start_date date,
End_date  date,
Campaign_Duration NUMBER(38,0),
Start_month VARCHAR(10),
End_month VARCHAR(10),
Start_Year INT,
End_Year INT)''')

# %%
success, nchunks, nrows, _ = write_pandas(conn, CAMPAIGN_DESC_RAW,'CAMPAIGN_DESC_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,30

# %%
success, nchunks, nrows, _ = write_pandas(conn, COUPON_REDEMPT_RAW,'COUPON_REDEMPT_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,2318

# %%
success, nchunks, nrows, _ = write_pandas(conn,TRANSACTION_RAW ,'TRANSACTION_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,450416

# %%
cur.close()
conn.close()

# %%
##CAMPAIGN_DESC_CLEANED = CAMPAIGN_DESC_RAW.copy()

# %%
##from sqlalchemy import create_engine

# %%
##connection_string = f"snowflake://{user}:{password}@{account}/{database}/{schema}?warehouse={warehouse}"

# %%
##engine = create_engine(connection_string)

# %%
##cur = conn.cursor()

# %%
##CAMPAIGN_DESC_RAW.to_sql(con=engine,name="CAMPAIGN_DESC_New",if_exists="append",index=False)

# %%
##COUPON_REDEMPT_RAW.to_sql(name="COUPON_REDEMPT_New",con=engine,if_exists="replace",index=False)

# %%
##TRANSACTION_RAW.to_sql(name="TRANSACTION_New",con=engine,if_exists="replace",index=False)

# %%
##TRANSACTION_RAW.shape

# %%
##TRANSACTION_RAW.to_csv('TRANSACTION.csv',index=False)

# %%
##chunk_size = 10000
##for chunk in pd.read_csv("TRANSACTION.csv", chunksize=chunk_size):
    ##chunk.to_sql('TRANSACTION_New',con= engine,if_exists='append', index=False)

# %%
##chunk_size = 16000

# %%
##chunks = [TRANSACTION_RAW[i:i+chunk_size] for i in range(0, len(TRANSACTION_RAW), chunk_size)]

# %%
##for chunk in chunks:
    ##chunk.to_sql(name="TRANSACTION_New", con=engine, if_exists='append', index=False)

# %%
##engine.dispose()

# %%
##programmingerror: (snowflake.connector.errors.programmingerror) 001042 (xx000): 
        ##sql compilation error: compilation memory exhausted
    
##(snowflake.connector.errors.ProgrammingError) 001795 (42601): SQL compilation error: error line 1 at position 187
##maximum number of expressions in a list exceeded, expected at most 16,384, got 100,000
